# %%
#Q1]write a python function that takes a list of numbers as input and returns a sum of all even numbers in the list?
numbers = input('Enter numbers to add , with " ," as seperator')
numbers = map(int, numbers.strip().split(','))

def even():
  return n%2 == 0

total = sum(filter(even, numbers))
print(f"sum of even numbers: {total}")

# %%
#Q2] create a python function that accept a string and return a reverse of that string?
def reverse_string(str):
  str1 = ""
  for i in str:
    str1 = i + str1
  return str1

# %%
#Q3] implement a python function that takes a list of integers and return a new list containing the square of each number?
def square(n):
  return n**2

lis = [1, 2, 3, 4, 5]
square_list = list(map(square, lis))
print(square_list)

# %%
 #Q4]write a python that checks if a given number is prime or not from 1 to 200?
 def is_prime(number):
    if number <= 1:
        return False
    if number <= 3:
        return True
    if number % 2 == 0 or number % 3 == 0:
        return False
    i = 5
    while i * i <= number:
        if number % i == 0 or number % (i + 2) == 0:
            return False
        i += 6
    return True
# Out:
#   File "<ipython-input-1-cbdc7ba013e8>", line 1
#     write a python that checks if a given number is prime or not from 1 to 200?
#                         ^
# SyntaxError: expected 'else' after 'if' expression

# %%
#5]create an iterator class that generate fibonacci sequence upto specified number of terms?
class Fibonacciiterator:
  def __init__(self, limit):
    self.limit = limit
    self.a = 0
    self.b = 1
    self.count = 0

    def __iter__(self):
       return self

  def __next__(self):
    if self.count >= self.limit:
      raise StopIteration

# %%
#6]write a generator function in python that yields the power of 2 upto a given exponent?
def power_of_two_generator(exponent):
    for i in range(exponent + 1):
        yield 2 ** i

# %%
#7]implement a generator function that reads a file line by line and yield each line as a string?
def read_file_lines(file_path):

  try:
    with open(file_path, 'r') as file:
        for line in file:
            yield line
  except FileNotFoundError:
    print(f"File '{file_path}' not found.")

# %%
 #8]use lambda function in python to sort a list of tuples based on the second element of each tuple?
 a = [(1, 3), (4, 1), (2, 2)]

 res = sorted(a, key=lambda x: x[1])
 print(res)
# Out:
# [(4, 1), (2, 2), (1, 3)]

# %%
#9]write a python programme that uses 'map()' to convert list of tempratures from celcius to Fahrenheit?
def celsius_to_Fahrenheit(celsius):
  return (celsius * 9/5) + 32

celsius_temperatures = [0, 10, 20, 30, 40]

fahrenheit_temperatures = list(map(celsius_to_Fahrenheit, celsius_temperatures))
print(fahrenheit_temperatures)
# Out:
# [32.0, 50.0, 68.0, 86.0, 104.0]

# %%
#10]create a python programme that uses filer to remove all the vowels from a given string?
def remove_vowels(string):
  vowels = 'aeiouAEIOU'
  return ''.join(filter(lambda x: x not in vowels, string))

# %%
#11] imagin a accounting routine used in a book shop. it works on a list with sublist which look like this:
#Order Number   Book Title and Author          Quantity     Price per Items
#34587          Learning python, Mark Lutz        4            40.95
#98762          Programming Python, Mark Lutz     5            56.80
#77226          Head First Python, Paul Barry     3            32.95
#88112          Einfuhrung in Python3, Bernd Klein 3           24.99
#write a pyhon programe, which returns a list with 2-tuples each tuple consist of the order number and the product of the price per item and the quantity. the product should be
#incresed by 10,-C if the value of the order is smaller than 100,00C
#write a python program using lambda and map

orders = [[34587, "Learning Python", 5, 48.95],
          [98762, "Programming Python", 3, 56.80],
          [77226, "Head First Python", 2, 32.95],
          [88112, "Einführung in Python3", 3, 24.99]
 ]

 def calculate_order_value(order):
    order_number, title, quantity, price_per_item = order
    total_value = quantity * price_per
    if total_value < 100:
        total_value += 10
    return (order_number, total_value)

order_values = list(map(calculate_order_value, orders))
print(order_values)
# Out:
#   File "<ipython-input-14-fc212b55979a>", line 17
#     def calculate_order_value(order):
#     ^
# IndentationError: unexpected indent
