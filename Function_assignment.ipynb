# %%
#Q1] what is the difference between function and method in python?
#Ans- A function is a block of code that performs a specific task, while a method is a function that belongs to an object.
#     A method is called on an object, while a function is called independently.

# %%
#Q2] explain concept of function argument and parameters in python?
#ans- in python function parameters are the variable listed inside the paranthesis in the function defination and arguments
#     are the values passed to the function when it is called.

# %%
#Q3] what are the different ways to define and call a function in python?
#Ans- in python , function can be defined using the def keyword followed by the function name and a set of paranthesis.
#     standard function, lambda function,nested function, recursive function, generator function
#     calling function is done by using the function name followed by a set of paranthesis.
#     1.positional arguments 2.keyword arguments 3.default arguments 4.variable length arguments

# %%
#Q4] what is the purpose of return statement in python function?
#Ans- the purpose of return statement in python function is to specify the value that the function should return when it is called.
#     exiting the function and returning the specified value.

# %%
#Q5] what are iterator in python and how they differ from iterable?
#Ans- an iterable is basically an object that any user can iterate over . An iterator is also an object that helps a user in iterating over a iterable.

# %%
#Q6] explain the concept of generators in python and how they are defined?
#Ans- in python generator is a function that returns an iterator that produces a sequence of values when iterated over.
#     generator are defined using yield keyword instead of return keyword.

# %%
#7] what are the advantages of using generators over regular function?
#Ans-the advantages of generator over regular function is that they are memory efficient and lazy evaluation.

# %%
#8] what is the lambda function in python and when is it typically used?
#Ans- in python, a lambda function is a concise way to define a small , single line function. its created lambda keyword and its typically used for short , immediate operations,often
 #    when passing a function as an argument to another function.
 #    1) short, simple task 2) passing function as argument 3)keeping code clean 4)data transformations.

# %%
#9] Explain the purpose and usage of the 'map()' function in python?
#Ans- map() function in python applies a given function to each item of an iterator that yields the result .its primary purpose is to transform or manipulate data in an iterable.
#     usage: the map() function takes two argument
#     function: the function to apply to each item in the ierable
#     iterable: the iterable to process.

# %%
#10]  what is the difference between 'map()', 'reduce()' and 'filter()' functions in python?
#Ans - map(): applies a given function to each item in an iterable and return an iterator that yields the result .it transform each element individually.
#      reduce(): applies a function cumulatively to the items of an iterable, reducing it to a single value.
#      filter(): create a new iterator containing only the item from the original iterable for which a given function returns True.

# %%
#11] using pen and paper write the internal mechanism for sum operation using reduce function on this given list[47,11'42'13]
#Ans- initialization: reduce starts with the first two elements of the list (47,11)
#     first application: the function (e.g lambda a, b: a+b) is applied to 47 and 11, resulting in 58
#     second application: the function is applied to the result of the first application (58) and 42, resulting in 100
#     third application: the function is applied to the result of the second application (100) and 13, resulting in 113
#     final result: the final result is 113
